# %%
import numpy as np 
import pandas as pd

# %%
file1 = pd.read_csv(r"C:\Users\aykut\OneDrive\Belgeler\GitHub\IH_RH_DA_FT_AUG_2022\Class_Materials\Case_Studies\Customer_Analysis_Case_Study\Data\file1.csv")
file2 = pd.read_csv(r"C:\Users\aykut\OneDrive\Belgeler\GitHub\IH_RH_DA_FT_AUG_2022\Class_Materials\Case_Studies\Customer_Analysis_Case_Study\Data\file2.csv")
file3 = pd.read_csv(r"C:\Users\aykut\OneDrive\Belgeler\GitHub\IH_RH_DA_FT_AUG_2022\Class_Materials\Case_Studies\Customer_Analysis_Case_Study\Data\file3.csv")

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file1_cols = [i.lower().replace(" ","_") for i in file1.columns]

file1.columns = file1_cols

# %%
file1.columns = file1_cols

# %%
file1.rename(columns = {'st':'state'},inplace=True)

file1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2_cols = [i.lower().replace(" ","_") for i in file2.columns]

file2.columns = file2_cols



file2.columns = file2_cols

file2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
file3_cols = [i.lower().replace(" ", "_") for i in file3.columns]

# %%
file3.columns = file3_cols

file3.columns

file3
file2
file1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def load_data():
    
    return pd.concat([file1,file2,file3],axis=0)

ca_df = load_data()

ca_df[:100]
# Out:
#    customer       state gender             education customer_lifetime_value  \
# 0   RB50392  Washington    NaN                Master                     NaN
# 1   QZ44356     Arizona      F              Bachelor              697953.59%
# 2   AI49188      Nevada      F              Bachelor             1288743.17%
# 3   WW63253  California      M              Bachelor              764586.18%
# 4   GA49547  Washington      M  High School or Below              536307.65%
# ..      ...         ...    ...                   ...                     ...
# 95  TV87155      Oregon    NaN              Bachelor             2094619.25%
# 96  KH48895          AZ    NaN                Master              837535.39%
# 97  NZ30757  California    NaN              Bachelor              480166.15%
# 98  RI22468          AZ    NaN              Bachelor              574594.33%
# 99  FZ30935      Oregon    NaN               College              606611.60%
#
# ...

# %% [markdown]
# income is missing value

# %% [markdown]
# missing value is considered float64

# %%
def drop_columns():
    ca_df.drop(columns = ["customer"],inplace=True)
    return ca_df

# %%
drop_columns()
# Out:
#            state gender             education customer_lifetime_value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      8141 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer_lifetime_value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly_premium_auto       9137 non-null   float64
#  6   number_of_open_complaints  9137 non-null   object
#  7   policy_type                9137 non-null   object
#  8   vehicle_class              9137 non-null   object
#  9   total_claim_amount         9137 non-null   float64
#  10  st                         996 non-null    object
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
ca_df['customer_lifetime_value'] = ca_df['customer_lifetime_value'].str.replace('%','')

# %%
ca_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
ca_df2 = ca_df[ca_df['customer_lifetime_value'].isna()==True]

# %%
ca_df1 = ca_df[ca_df['customer_lifetime_value'].isna() == False]

# %%
ca_df1['customer_lifetime_value'] = pd.to_numeric(ca_df1['customer_lifetime_value'],errors = 'coerce')
# Out:
# C:\Users\aykut\AppData\Local\Temp\ipykernel_28208\1720867657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_df1['customer_lifetime_value'] = pd.to_numeric(ca_df1['customer_lifetime_value'],errors = 'coerce')

# %%
ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value']/100
# Out:
# C:\Users\aykut\AppData\Local\Temp\ipykernel_28208\3980021999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value']/100

# %%
ca_df1
# Out:
#           state gender             education  customer_lifetime_value  \
# 1       Arizona      F              Bachelor                6979.5359
# 2        Nevada      F              Bachelor               12887.4317
# 3    California      M              Bachelor                7645.8618
# 4    Washington      M  High School or Below                5363.0765
# 5        Oregon      F              Bachelor                8256.2978
# ..          ...    ...                   ...                      ...
# 991         NaN      M                Master                8471.4175
# 992         NaN      F               College                5431.2191
# 993         NaN      F               College                5689.6441
# 994         NaN      F                Master                3686.7238
# 995         NaN      M              Bachelor                3992.5839
#
#       income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
import math

# %%
type(ca_df['customer_lifetime_value'][0])
# Out:
# numpy.float64

# %%
ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value'].apply(np.ceil)
# Out:
# C:\Users\aykut\AppData\Local\Temp\ipykernel_28208\193121097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value'].apply(np.ceil)

# %%
ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value'].astype(str).apply(lambda x:x.replace(".0",""))
# Out:
# C:\Users\aykut\AppData\Local\Temp\ipykernel_28208\4223209151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value'].astype(str).apply(lambda x:x.replace(".0",""))

# %%
ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value'].astype(int)
# Out:
# C:\Users\aykut\AppData\Local\Temp\ipykernel_28208\3171806581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_df1['customer_lifetime_value'] = ca_df1['customer_lifetime_value'].astype(int)

# %%
ca_df1
# Out:
#           state gender             education  customer_lifetime_value  \
# 1       Arizona      F              Bachelor                     6980
# 2        Nevada      F              Bachelor                    12888
# 3    California      M              Bachelor                     7646
# 4    Washington      M  High School or Below                     5364
# 5        Oregon      F              Bachelor                     8257
# ..          ...    ...                   ...                      ...
# 991         NaN      M                Master                     8472
# 992         NaN      F               College                     5432
# 993         NaN      F               College                     5690
# 994         NaN      F                Master                     3687
# 995         NaN      M              Bachelor                     3993
#
#       income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
ca_df = pd.concat([ca_df1,ca_df2],axis = 0)

# %%
ca_df
# Out:
#            state gender             education customer_lifetime_value  \
# 1        Arizona      F              Bachelor                    6980
# 2         Nevada      F              Bachelor                   12888
# 3     California      M              Bachelor                    7646
# 4     Washington      M  High School or Below                    5364
# 5         Oregon      F              Bachelor                    8257
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                     NaN
# 7066  California      F               College                     NaN
# 7067  California      M              Bachelor                     NaN
# 7068  California      M               College                     NaN
# 7069  California      M               College                     NaN
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
ca_df['number_of_open_complaints'].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 0,
#        2, 3, 1, 5, 4], dtype=object)

# %%
ca_df_open_comp = ca_df['number_of_open_complaints']

# %%
 i    for i in ca_df_open_comp
# Out:
# 1       1/0/00
# 2       1/0/00
# 3       1/0/00
# 4       1/0/00
# 5       1/0/00
#          ...
# 7065         0
# 7066         0
# 7067         3
# 7068         0
# 7069         0
# Name: number_of_open_complaints, Length: 12074, dtype: object
